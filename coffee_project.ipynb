# %% [markdown]
# # **Introduction**
# Coffee is one of the most popular and universal beverages in this day and age. According to Sratista, approximately 166.63 million 60kg coffee bags were consumed worldwide in 2020-2021 (Statista 2023) . As it is also a necessity in multiple regions around the world, the value of coffee has gained not only economical, but also societal and cultural importance. Cafes, for example, have now become trendy with many students, especially, enjoying the aesthetics of studying with a ‘for-here’ mug of good coffee. Most importantly, the largest contributor for whether coffee is profitable or not is the quality of the beans consumed.Although it can be locally farmed, the major coffee-producing regions are located along the ‘Bean Belt’; which includes Central and South America, Africa, and the Middle East and South Asia (Halo Coffee, 2020). There are also two main species for the coffee beans used today: Arabica and Robusta, with the most popular being Arabica.
#
# Our aim for this exploratory analysis as fellow coffee enthusiasts, is to identify the most versatile and profitable coffee bean that cafes should use in order to be the most successful. In order to identify this bean, we will use the country of origin and region in which it was produced. By versatility, we mean the coffee bean that is the most flavourful, long-lasting, and resilient. This will be defined by specified ranges of variables we will be testing, in which the qualitative ones are readily given a score from 0-10. All of thiswill allow us to find the bean of highest quality

# %% [markdown]
# **Our Question**
#
# What is the most profitable and versatile coffee bean that cafes should use? (as identified by the country of origin and region produced)

# %% [markdown]
# **Our Dataset**
#
#   We are using a dataset from the Coffee Quality Institute made in 2018. The dataset was collected by James LeDoux, who is a data scientist at Buzzfeed, and refined by Diego Volpatto, who is a Scientific Developer at the National Laboratory for Scientific Computing. The data is collected on both Arabica and Robusta coffee beans (majority being Arabica as they are the more popular bean), and rated on a 0-100 scale based on characteristics such as aroma, sweetness, acidity, body, etc. The country/region of origin is also recorded per type of coffee bean, alongside their species, harvest and expiration date, defects, etc. There are 1340 observations in the datatset with 43 variables (18 numeric variables and 25 categorical variables).

# %% [markdown]
# # **Preliminary exploratory data analysis**

# %% [markdown]
# First, we can load the packages necessary to cleaning and wrangling the data set we are working with. This includes pandas, altair, scipy, datetime, and sklearn. We will be using more packages later on further in the analysis.

# %%
import pandas as pd
import altair as alt 
import scipy 
import datetime
import sklearn

# %%
url = "https://github.com/nazie23/dsci-100-project-group-9/blob/main/merged_data_cleaned.csv?raw=true"
coffee = pd.read_csv(url, index_col=0)
coffee=coffee[["Species",'Country.of.Origin','Region','Harvest.Year','Processing.Method','Aroma','Flavor','Aftertaste','Acidity','Balance','Uniformity','Moisture','Category.One.Defects','Category.Two.Defects','Expiration','altitude_mean_meters']]
coffee['Expiration'] =[i[-4:] for i in coffee['Expiration']]

# coffee = coffee[coffee['altitude_mean_meters']>1200]

coffee
# Out:
#       Species Country.of.Origin                         Region Harvest.Year  \
# 0     Arabica          Ethiopia                   guji-hambela         2014
# 1     Arabica          Ethiopia                   guji-hambela         2014
# 2     Arabica         Guatemala                            NaN          NaN
# 3     Arabica          Ethiopia                         oromia         2014
# 4     Arabica          Ethiopia                   guji-hambela         2014
# ...       ...               ...                            ...          ...
# 1334  Robusta           Ecuador               san juan, playas         2016
# 1335  Robusta           Ecuador               san juan, playas         2016
# 1336  Robusta     United States  kwanza norte province, angola         2014
# 1337  Robusta             India                            NaN         2013
# 1338  Robusta           Vietnam                            NaN         2013
#
#      Processing.Method  Aroma  Flavor  Aftertaste  Acidity  Balance  \
# 0         Washed / Wet   8.67    8.83        8.67     8.75     8.42
# 1         Washed / Wet   8.75    8.67        8.50     8.58     8.42
# 2                  NaN   8.42    8.50        8.42     8.42     8.42
# 3        Natural / Dry   8.17    8.58        8.42     8.42     8.25
# 4         Washed / Wet   8.25    8.50        8.25     8.50     8.33
# ...                ...    ...     ...         ...      ...      ...
# 1334               NaN   7.75    7.58        7.33     7.58     7.83
# 1335               NaN   7.50    7.67        7.75     7.75     5.25
# 1336     Natural / Dry   7.33    7.33        7.17     7.42     7.17
# 1337     Natural / Dry   7.42    6.83        6.75     7.17     7.00
# 1338     Natural / Dry   6.75    6.67        6.50     6.83     6.83
#
#       Uniformity  Moisture  Category.One.Defects  Category.Two.Defects  \
# 0          10.00      0.12                     0                     0
# 1          10.00      0.12                     0                     1
# 2          10.00      0.00                     0                     0
# 3          10.00      0.11                     0                     2
# 4          10.00      0.12                     0                     2
# ...          ...       ...                   ...                   ...
# 1334       10.00      0.00                     0                     1
# 1335       10.00      0.00                     0                     0
# 1336        9.33      0.00                     0                     6
# 1337        9.33      0.10                    20                     1
# 1338        9.33      0.12                    63                     9
#
#      Expiration  altitude_mean_meters
# 0          2016                2075.0
# 1          2016                2075.0
# 2          2011                1700.0
# 3          2016                2000.0
# 4          2016                2075.0
# ...         ...                   ...
# 1334       2017                   NaN
# 1335       2017                  40.0
# 1336       2015                 795.0
# 1337       2015                   NaN
# 1338       2015                   NaN
#
# [1339 rows x 16 columns]

# %% [markdown]
# *Table 1.1- Preview of the coffee dataset*
#
# Our dataset is a *.csv* file so we can use the *read_csv* function and filter it to only provide columns relevant to our criteria.

# %% [markdown]
# We can also gain a better understanding of our raw data's spread and median values by collecting some summary statistics.

# %%
summary_table = coffee.describe()[1:]
summary_table
# Out:
#          Aroma    Flavor  Aftertaste   Acidity   Balance  Uniformity  \
# mean  7.566706  7.520426    7.401083  7.535706  7.518013    9.834877
# std   0.377560  0.398442    0.404463  0.379827  0.408943    0.554591
# min   0.000000  0.000000    0.000000  0.000000  0.000000    0.000000
# 25%   7.420000  7.330000    7.250000  7.330000  7.330000   10.000000
# 50%   7.580000  7.580000    7.420000  7.580000  7.500000   10.000000
# 75%   7.750000  7.750000    7.580000  7.750000  7.750000   10.000000
# max   8.750000  8.830000    8.670000  8.750000  8.750000   10.000000
#
#       Moisture  Category.One.Defects  Category.Two.Defects  \
# mean  0.088379              0.479462              3.556385
# std   0.048287              2.549683              5.312541
# min   0.000000              0.000000              0.000000
# 25%   0.090000              0.000000              0.000000
# 50%   0.110000              0.000000              2.000000
# 75%   0.120000              0.000000              4.000000
# max   0.280000             63.000000             55.000000
#
#       altitude_mean_meters
# mean           1775.030545
# std            8668.626080
# min               1.000000
# 25%            1100.000000
# 50%            1310.640000
# 75%            1600.000000
# max          190164.000000

# %% [markdown]
# *Table 1.2 - A summary table displaying a statistical analysis of the entire dataset*

# %%
arabica = len(coffee[coffee['Species']=="Arabica"])
robusta = len(coffee[coffee['Species']=="Robusta"])
print(arabica,robusta)
# Out:
# 1311 28

# %% [markdown]
# Noticing the two species coffee beans are available in, we can get a sense of how evenly distributed the species *Arabica* and *Robusta* are in comparison to one another.

# %%
chart_1= alt.Chart(coffee).mark_bar().encode(x=alt.X("Species"), y=alt.Y("count()"),color=alt.Color("Species",scale=alt.Scale(scheme="rainbow")), tooltip=['Moisture','Aftertaste','Region', 'Country.of.Origin']).interactive()
chart_1
# Out:
# alt.Chart(...)

# %% [markdown]
# *Chart 1.1 - A bar chart displaying the distribution of species of beans in the dataset*

# %% [markdown]
# As shown above, there is a much greater number of *Arabica* beans compared to R*obusta*, which gives us a sense that there is a high probability our ideal bean will be of the species *Arabica*.

# %% [markdown]
# # **Methods**
#
# We have a set of criteria based on research in which we have an optimal range for each of the variables we are using to answer our question. Afterwards, basedon the ranked priorities, we will construct a cost function. The most versatile bean will be distinguished by a special custom cost function which will weight the different characteristics based on our preferences to find the bean that we believe will be the best bean. This function will add weights to the addition of all these factors and the maximization of this cost function will provide the basis of our identification. This will help us identify the closest bean with regards to all other beans in the subset. This criteria can be seen below:
#
# **Defined Ranges for High Coffee Quality:**
#
# Category 1/2 Defects (number):
#
# *The less defects the higher quality*
#
# Mean Altitude (meters):
#
# *A minimum of 1200 meters is needed for higher quality. Generally the higher altitude the better. Greater than 1200 meters
# (Fleisher 2017)*
#
# Flavour(scale 0-10):
#
# *Greater than or equal to 8*
#
# Processing method (type):
#
# *Washed process is the best method as it is “able to highlgight the true character of single origin beans like no other process” ( Jack Mormon Coffee Co.2021)*
#
#
# Expiration (years before expiration):
#
# *The longer it lasts, the more versatile the bean*
#
# Balance(scale 0-10):
#
# *Greater than or equal to 8*
#
# Acidity(scale 0-10):
#
# *Dependent on desired flavour type; thus, is still desired (greater than 0) but not dependent on score*
#
# Aftertaste(scale 0-10):
#
# *Greater than or equal to 8*
#
# Aroma(scale 0-10):
#
# *Greater than or equal to 8*
#
# Uniformity(scale 0-10):
#
# *The more uniform the coffee beans are, the more reliable*
#
#
# Other variables that might play a role: - helps with class identification of the bean:
#
# *Species: (a variable, does not affect prediction)*
#
# *Country of Origin*
#
# *Region*

# %% [markdown]
# # **Impacts**
#
# Our explatory analysis can help cafes identify which coffee bean of the highest quality to buyand use to be the most profitable. It will also give us an idea of the ideal and optimal conditions for coffee growth and production, as shown by the region and country of origin.
#
# **Further Questions**
#
# This could lead to further questions about the costs of high-quality coffee production and potentially the most resilient coffee bean that is the most affordable can withstand less than ideal conditions.

# %% [markdown]
#   We can start by importing the packages that we need to perform our analysis. The first step would be to scale all the variables so that they are comparable with one another. To do this, we make a preprocessor with our desired variable. Note that we are not using Mean Altitude yet. Since Mean Altitude is preferred in the highest ranges, we will generate our prediction using the model and at the very end assess whether our result is rational and makes sense based on the mean altitude of the class region.

# %% [markdown]
# # **Scaling the Data**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import make_pipeline
from sklearn import cluster, datasets, metrics
from sklearn.cluster import KMeans


preprocessor = make_column_transformer(
    (StandardScaler(), ["Aroma", "Flavor","Aftertaste", "Acidity","Balance","Uniformity"])
)

preprocessor
# Out:
# ColumnTransformer(transformers=[('standardscaler', StandardScaler(),
#                                  ['Aroma', 'Flavor', 'Aftertaste', 'Acidity',
#                                   'Balance', 'Uniformity'])])

# %% [markdown]
# We have made a preprocessor that will scale our numerical predictors. Now we can make a new object containing our scaled data by fitting our original datset into the preprocessor made above and specifying the columns that we are using. Using dropna( ), the NaN values that are present in the data will be neglected so that we only have numeric values.

# %%
coffee
# Out:
#       Species Country.of.Origin                         Region Harvest.Year  \
# 0     Arabica          Ethiopia                   guji-hambela         2014
# 1     Arabica          Ethiopia                   guji-hambela         2014
# 2     Arabica         Guatemala                            NaN          NaN
# 3     Arabica          Ethiopia                         oromia         2014
# 4     Arabica          Ethiopia                   guji-hambela         2014
# ...       ...               ...                            ...          ...
# 1334  Robusta           Ecuador               san juan, playas         2016
# 1335  Robusta           Ecuador               san juan, playas         2016
# 1336  Robusta     United States  kwanza norte province, angola         2014
# 1337  Robusta             India                            NaN         2013
# 1338  Robusta           Vietnam                            NaN         2013
#
#      Processing.Method  Aroma  Flavor  Aftertaste  Acidity  Balance  \
# 0         Washed / Wet   8.67    8.83        8.67     8.75     8.42
# 1         Washed / Wet   8.75    8.67        8.50     8.58     8.42
# 2                  NaN   8.42    8.50        8.42     8.42     8.42
# 3        Natural / Dry   8.17    8.58        8.42     8.42     8.25
# 4         Washed / Wet   8.25    8.50        8.25     8.50     8.33
# ...                ...    ...     ...         ...      ...      ...
# 1334               NaN   7.75    7.58        7.33     7.58     7.83
# 1335               NaN   7.50    7.67        7.75     7.75     5.25
# 1336     Natural / Dry   7.33    7.33        7.17     7.42     7.17
# 1337     Natural / Dry   7.42    6.83        6.75     7.17     7.00
# 1338     Natural / Dry   6.75    6.67        6.50     6.83     6.83
#
#       Uniformity  Moisture  Category.One.Defects  Category.Two.Defects  \
# 0          10.00      0.12                     0                     0
# 1          10.00      0.12                     0                     1
# 2          10.00      0.00                     0                     0
# 3          10.00      0.11                     0                     2
# 4          10.00      0.12                     0                     2
# ...          ...       ...                   ...                   ...
# 1334       10.00      0.00                     0                     1
# 1335       10.00      0.00                     0                     0
# 1336        9.33      0.00                     0                     6
# 1337        9.33      0.10                    20                     1
# 1338        9.33      0.12                    63                     9
#
#      Expiration  altitude_mean_meters
# 0          2016                2075.0
# 1          2016                2075.0
# 2          2011                1700.0
# 3          2016                2000.0
# 4          2016                2075.0
# ...         ...                   ...
# 1334       2017                   NaN
# 1335       2017                  40.0
# 1336       2015                 795.0
# 1337       2015                   NaN
# 1338       2015                   NaN
#
# [1339 rows x 16 columns]

# %% [markdown]
# *Table 1.3- Coffee data set before cleaning and wrangling*

# %%
coffee_scaled = pd.DataFrame(preprocessor.fit_transform(coffee),columns=["Aroma", "Flavor","Aftertaste", "Acidity","Balance",	"Uniformity"])
coffee_scaled = coffee_scaled.dropna() 

#split data into training and testing set in 70 and 30%
coffee_scaled
coffee_scaled_train,coffee_scaled_test=train_test_split(coffee_scaled,test_size=0.3)

# %% [markdown]
# After having scaled our data, we will split it into both a training and test set. 70% training and 30% testing is a reasonable split because it can allow us to train our model using the training set and then assess the accuracy using the test set.

# %% [markdown]
# The first method we will be using to answer our question is clustering. If we make clusters based on our most desired values of the criteria, we can narrow down the selection of beans so that the most desirable cluster will be most likely to have the most proftable bean. Our reference points for this will be flavour, aroma, aftertaste and acidity, as these are the variables that we would like to maximize for the highest quality and most profitable bean to be used and served in a cafe. We will only be using the 70% training data when performing the clustering method so that we do not bias our model. Then we will extract the most desirable clusters based on the best k-values.

# %% [markdown]
# # **Clustering**

# %%
coffee_ks=pd.DataFrame({"k":range(1, 70)})
coffee_clustering= coffee_ks.assign(models=coffee_ks["k"].apply(lambda x: KMeans(n_clusters=x, random_state=1234, n_init="auto").fit(coffee_scaled_train)))
coffee_clustering
# Out:
#      k                                             models
# 0    1  KMeans(n_clusters=1, n_init='auto', random_sta...
# 1    2  KMeans(n_clusters=2, n_init='auto', random_sta...
# 2    3  KMeans(n_clusters=3, n_init='auto', random_sta...
# 3    4  KMeans(n_clusters=4, n_init='auto', random_sta...
# 4    5  KMeans(n_clusters=5, n_init='auto', random_sta...
# ..  ..                                                ...
# 64  65  KMeans(n_clusters=65, n_init='auto', random_st...
# 65  66  KMeans(n_clusters=66, n_init='auto', random_st...
# 66  67  KMeans(n_clusters=67, n_init='auto', random_st...
# 67  68  KMeans(n_clusters=68, n_init='auto', random_st...
# 68  69  KMeans(n_clusters=69, n_init='auto', random_st...
#
# [69 rows x 2 columns]

# %% [markdown]
# *Table 2.0 - Table containing the KMeans function for the number of clusters in the range*

# %% [markdown]
# We used a k range of 70 because it seems like a reasonable range that will not underfit or overfit the available data and increase variance in our model, causing inaccuracy in our prediction. We will perform clustering on the 2-3 top values of k. For each cluster we achieve, we will split the data once again into an 80 training to 20 test split so as to train our model using only the training set and perform cross-validation and evaluate accuracy on the 20% of test data.

# %%
coffee_model_stats=coffee_clustering.assign(model_statistics=coffee_clustering["models"].apply(lambda x: x.inertia_))
coffee_model_stats
# Out:
#      k                                             models  model_statistics
# 0    1  KMeans(n_clusters=1, n_init='auto', random_sta...       6329.982687
# 1    2  KMeans(n_clusters=2, n_init='auto', random_sta...       4194.013448
# 2    3  KMeans(n_clusters=3, n_init='auto', random_sta...       2639.384650
# 3    4  KMeans(n_clusters=4, n_init='auto', random_sta...       2097.967172
# 4    5  KMeans(n_clusters=5, n_init='auto', random_sta...       1728.210516
# ..  ..                                                ...               ...
# 64  65  KMeans(n_clusters=65, n_init='auto', random_st...        402.444912
# 65  66  KMeans(n_clusters=66, n_init='auto', random_st...        397.731633
# 66  67  KMeans(n_clusters=67, n_init='auto', random_st...        394.836184
# 67  68  KMeans(n_clusters=68, n_init='auto', random_st...        384.150647
# 68  69  KMeans(n_clusters=69, n_init='auto', random_st...        386.698685
#
# [69 rows x 3 columns]

# %% [markdown]
# *Table 2.1- K-values with Sum of Squared Error (model statistics)*

# %% [markdown]
# Next, the knn clustering is tested using a range of 1-70 clusters to determine which value of k would cause the smallest inertia. This was done by creating an elbow plot, from which we could visually choose the value that has the most dramatic reduction in inertia.

# %%
coffee_plot=alt.Chart(coffee_model_stats[["k","model_statistics"]]).mark_line(point=True).encode(x="k",y="model_statistics")
coffee_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# *Chart 2.1 - An elbow plot displaying which k value would be the best number of clusters to use on our dataset*

# %% [markdown]
# From the elbow plot, it is found that the graph has the most prominent "elbow" at  the values of k=5, k=6, and k=7 so these quantities of clusters would be the most accurate. We will then create 3 different plots using 5, 6 and 7 clusters to choose the cluster value with the most accuracy, then pick the cluster that has the most desirable traits.

# %%
coffee_cluster_k5 = KMeans(n_clusters=5, random_state=1234)
tidy_coffee_cluster_k5 = coffee_cluster_k5.fit(coffee_scaled_train).predict(coffee_scaled_train)
tidy_coffee_cluster_k5_df = coffee_scaled_train.assign(cluster=tidy_coffee_cluster_k5)
tidy_coffee_cluster_k5_df["Species"]=coffee["Species"]
tidy_coffee_cluster_k5_df["Country of Origin"]=coffee["Country.of.Origin"]
tidy_coffee_cluster_k5_df["Region"]=coffee["Region"]
tidy_coffee_cluster_k5_df
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#          Aroma    Flavor  Aftertaste   Acidity   Balance  Uniformity  cluster  \
# 1063 -0.388710 -0.678961   -0.175812 -1.410922 -0.655625     0.29785        3
# 1198 -0.627172 -0.879818   -2.030813 -0.304742 -1.683046     0.29785        3
# 476  -0.388710  0.777252    1.901790  1.433542  0.151634     0.29785        2
# 980  -0.627172 -1.105782   -0.175812 -0.752481  0.151634     0.29785        3
# 1325  1.148044  0.375538    0.862989 -0.094040  0.151634     0.29785        2
# ...        ...       ...         ...       ...       ...         ...      ...
# 355   0.273684  0.576395    0.244655  0.775101  0.151634     0.29785        0
# 831  -0.388710  0.149574   -0.373679 -0.094040 -0.044065     0.29785        0
# 1013 -0.627172 -0.879818   -0.373679 -0.541780 -0.655625     0.29785        3
# 946  -0.388710 -0.252140   -0.373679 -0.752481 -0.459926     0.29785        0
# 209   1.598472  0.576395    0.442522  0.353699  0.151634     0.29785        2
#
#       Species Country of Origin              Region
# 1063  Arabica            Brazil      south of minas
# 1198  Arabica         Guatemala             oriente
# 476   Arabica       El Salvador           santa ana
# 980   Arabica        Costa Rica      central valley
# 1325  Robusta            Uganda       south western
# ...       ...               ...                 ...
# 355   Arabica         Guatemala             oriente
# 831   Arabica            Brazil        grama valley
# 1013  Arabica            Taiwan              taiwan
# 946   Arabica            Mexico  coatepec, coatepec
# 209   Arabica            Uganda              kasese
#
# [937 rows x 10 columns]

# %% [markdown]
# *Table 2.2- K-clustering based on k=5.*

# %%
coffee_cluster_k6 = KMeans(n_clusters=6,random_state=1234)
tidy_coffee_cluster_k6 = coffee_cluster_k6.fit(coffee_scaled_train).predict(coffee_scaled_train)
tidy_coffee_cluster_k6_df = coffee_scaled_train.assign(cluster=tidy_coffee_cluster_k6)
tidy_coffee_cluster_k6_df["Species"]=coffee["Species"]
tidy_coffee_cluster_k6_df["Country of Origin"]=coffee["Country.of.Origin"]
tidy_coffee_cluster_k6_df["Region"]=coffee["Region"]
tidy_coffee_cluster_k6_df
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#          Aroma    Flavor  Aftertaste   Acidity   Balance  Uniformity  cluster  \
# 1063 -0.388710 -0.678961   -0.175812 -1.410922 -0.655625     0.29785        0
# 1198 -0.627172 -0.879818   -2.030813 -0.304742 -1.683046     0.29785        4
# 476  -0.388710  0.777252    1.901790  1.433542  0.151634     0.29785        2
# 980  -0.627172 -1.105782   -0.175812 -0.752481  0.151634     0.29785        0
# 1325  1.148044  0.375538    0.862989 -0.094040  0.151634     0.29785        3
# ...        ...       ...         ...       ...       ...         ...      ...
# 355   0.273684  0.576395    0.244655  0.775101  0.151634     0.29785        3
# 831  -0.388710  0.149574   -0.373679 -0.094040 -0.044065     0.29785        0
# 1013 -0.627172 -0.879818   -0.373679 -0.541780 -0.655625     0.29785        0
# 946  -0.388710 -0.252140   -0.373679 -0.752481 -0.459926     0.29785        0
# 209   1.598472  0.576395    0.442522  0.353699  0.151634     0.29785        3
#
#       Species Country of Origin              Region
# 1063  Arabica            Brazil      south of minas
# 1198  Arabica         Guatemala             oriente
# 476   Arabica       El Salvador           santa ana
# 980   Arabica        Costa Rica      central valley
# 1325  Robusta            Uganda       south western
# ...       ...               ...                 ...
# 355   Arabica         Guatemala             oriente
# 831   Arabica            Brazil        grama valley
# 1013  Arabica            Taiwan              taiwan
# 946   Arabica            Mexico  coatepec, coatepec
# 209   Arabica            Uganda              kasese
#
# [937 rows x 10 columns]

# %% [markdown]
# *Table 2.3- K-clustering based on k=6.*

# %%
coffee_cluster_k7 = KMeans(n_clusters=7, random_state=1234)
tidy_coffee_cluster_k7 = coffee_cluster_k7.fit(coffee_scaled_train).predict(coffee_scaled_train)
tidy_coffee_cluster_k7_df = coffee_scaled_train.assign(cluster=tidy_coffee_cluster_k6)
tidy_coffee_cluster_k7_df["Species"]=coffee["Species"]
tidy_coffee_cluster_k7_df["Country of Origin"]=coffee["Country.of.Origin"]
tidy_coffee_cluster_k7_df["Region"]=coffee["Region"]
tidy_coffee_cluster_k7_df
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#          Aroma    Flavor  Aftertaste   Acidity   Balance  Uniformity  cluster  \
# 1063 -0.388710 -0.678961   -0.175812 -1.410922 -0.655625     0.29785        0
# 1198 -0.627172 -0.879818   -2.030813 -0.304742 -1.683046     0.29785        4
# 476  -0.388710  0.777252    1.901790  1.433542  0.151634     0.29785        2
# 980  -0.627172 -1.105782   -0.175812 -0.752481  0.151634     0.29785        0
# 1325  1.148044  0.375538    0.862989 -0.094040  0.151634     0.29785        3
# ...        ...       ...         ...       ...       ...         ...      ...
# 355   0.273684  0.576395    0.244655  0.775101  0.151634     0.29785        3
# 831  -0.388710  0.149574   -0.373679 -0.094040 -0.044065     0.29785        0
# 1013 -0.627172 -0.879818   -0.373679 -0.541780 -0.655625     0.29785        0
# 946  -0.388710 -0.252140   -0.373679 -0.752481 -0.459926     0.29785        0
# 209   1.598472  0.576395    0.442522  0.353699  0.151634     0.29785        3
#
#       Species Country of Origin              Region
# 1063  Arabica            Brazil      south of minas
# 1198  Arabica         Guatemala             oriente
# 476   Arabica       El Salvador           santa ana
# 980   Arabica        Costa Rica      central valley
# 1325  Robusta            Uganda       south western
# ...       ...               ...                 ...
# 355   Arabica         Guatemala             oriente
# 831   Arabica            Brazil        grama valley
# 1013  Arabica            Taiwan              taiwan
# 946   Arabica            Mexico  coatepec, coatepec
# 209   Arabica            Uganda              kasese
#
# [937 rows x 10 columns]

# %% [markdown]
# *Table 2.4- K-clustering based on k=7.*

# %% [markdown]
# After plotting different combinations of our standardised variables to create a scatter matrix, we can see that there are a total of 5 clusters. By colour-coding each cluster, it is most evident that cluster 3, coloured in magenta, is most often identified towards the top right, which indicates the highest values of our variables. Since the majority of the variables require points higher than or equal to 8 as determined by the criteria, cluster 3 will most likely contain the bean that scores highest on all our criteria and therefore be the most profitable. This was obtainied from k=5. A similar scatter matrix will be created from the values of k=6 and k=7.

# %%
tidy_coffee_cluster_k5_plot=alt.Chart(tidy_coffee_cluster_k5_df).mark_point(opacity=0.25).encode(
    x=alt.X(alt.repeat("row"),type="quantitative"),
    y=alt.Y(alt.repeat("column"),type="quantitative"),
    color=alt.Color("cluster",scale=alt.Scale(scheme="accent")),
   tooltip =["Species","Country of Origin","Region","Aroma", "Flavor","Aftertaste", "Acidity","Balance",	"Uniformity","cluster"]).repeat(
        row=["Aroma", "Flavor","Aftertaste", "Acidity"],
        column=["Balance",	"Uniformity"]
    ).interactive()

tidy_coffee_cluster_k5_df_untouched=tidy_coffee_cluster_k5_df

tidy_coffee_cluster_k5_plot
# Out:
# alt.RepeatChart(...)

# %% [markdown]
# *Figure 2.0- Scatter matrix created using k=5. Cluster 3 in the magenta/pink is shown towards the top-right in all cases.*

# %%
tidy_coffee_cluster_k6_plot=alt.Chart(tidy_coffee_cluster_k6_df).mark_point(opacity=0.25).encode(
    x=alt.X(alt.repeat("row"),type="quantitative"),
    y=alt.Y(alt.repeat("column"),type="quantitative"),
    color=alt.Color("cluster",scale=alt.Scale(scheme="accent")),
   tooltip =["Species","Country of Origin","Region","Aroma", "Flavor","Aftertaste", "Acidity","Balance",	"Uniformity","cluster"]).repeat(
        row=["Aroma", "Flavor","Aftertaste", "Acidity"],
        column=["Balance",	"Uniformity"]
    ).interactive()

tidy_coffee_cluster_k6_df_untouched=tidy_coffee_cluster_k6_df

tidy_coffee_cluster_k6_plot
# Out:
# alt.RepeatChart(...)

# %% [markdown]
# Figure 2.1- Scatter matrix created using k=6. Cluster 3 in the light green is shown towards the top-right in all cases.

# %%
tidy_coffee_cluster_k7_plot=alt.Chart(tidy_coffee_cluster_k7_df).mark_point(opacity=0.25).encode(
    x=alt.X(alt.repeat("row"),type="quantitative"),
    y=alt.Y(alt.repeat("column"),type="quantitative"),
    color=alt.Color("cluster",scale=alt.Scale(scheme="accent")),
   tooltip =["Species","Country of Origin","Region","Aroma", "Flavor","Aftertaste", "Acidity","Balance",	"Uniformity","cluster"]).repeat(
        row=["Aroma", "Flavor","Aftertaste", "Acidity"],
        column=["Balance",	"Uniformity"]
    ).interactive()

tidy_coffee_cluster_k7_df_untouched=tidy_coffee_cluster_k7_df

tidy_coffee_cluster_k7_plot
# Out:
# alt.RepeatChart(...)

# %% [markdown]
# *Figure 2.2- Scatter matrix created using k=7. Cluster 3 in the light green is shown towards the top-right in all cases*

# %%
tidy_coffee_cluster_k5_df=tidy_coffee_cluster_k5_df[tidy_coffee_cluster_k5_df["cluster"]==3]
tidy_coffee_cluster_k5_df=tidy_coffee_cluster_k5_df.dropna()

tidy_coffee_cluster_k6_df=tidy_coffee_cluster_k6_df[tidy_coffee_cluster_k6_df["cluster"]==3]
tidy_coffee_cluster_k6_df=tidy_coffee_cluster_k6_df.dropna()

tidy_coffee_cluster_k7_df=tidy_coffee_cluster_k7_df[tidy_coffee_cluster_k7_df["cluster"]==3]
tidy_coffee_cluster_k7_df=tidy_coffee_cluster_k7_df.dropna()

# %% [markdown]
# As shown from the scatter matrices generated above, for the k-value of 5, cluster 3 has the highest probability of containing our most ideal bean for all 3 values. This is reliable because we know that our answer will lie within that cluster. To make sure the data points in the cluster do not contain NaN values, we use *dropna()*.
#
# Based on the data points available in the cluster, we will be running a KNN Classification analysis to find the bean with the most desirable traits. We start by splitting the data in each of our generated clusters into 80 training: 20 testing of which we will train our model using the 80% and find the accuracy with the remaining 20% test.

# %% [markdown]
# # **KNN-Classification Analysis**

# %% [markdown]
# Moving on to the next part of our analysis, we will perform the KNN-Classification based on the k nearest neighbours to predict the classification of our most ideal bean.
#
# We begin by setting a *random seed* so that our steps are reproducible. Then we create a pipeline to fit our training data into, using both our preprocessor for the scaled data as well as the *KNeighbors Classifier*.
#  Once again, we will assume a range of up to 70 for k and perform cross-validation with approximately 5 folds so that we do not overexert our model. Afterwards, a new GridSearch is formed for each cluster with our parameters for k value between 1 and 70. Next we fit the GridSearch model to our desired parameters. Plotting our results, a line plot is generated with each of the k values in our range and their corresponding mean test score.

# %%
#Assesing best k FOR K CLASSIFIER
import altair as alt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV, cross_validate
from sklearn.neighbors import KNeighborsClassifier

np.random.seed(1234)

classifier_coffee_scaled_train, classifier_coffee_scaled_test = train_test_split(tidy_coffee_cluster_k5_df,test_size=0.2)
classifier_coffee_scaled_train=classifier_coffee_scaled_train.dropna()
classifier_coffee_scaled_test=classifier_coffee_scaled_test.dropna()
X_train_1 = classifier_coffee_scaled_train[["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"]]
y_train_1 = classifier_coffee_scaled_train[["Species", "Country of Origin", "Region"]]
param_grid = { "kneighborsclassifier__n_neighbors": range(1, 70)}

pipeline = make_pipeline(preprocessor,KNeighborsClassifier())
# v_fold_score = cross_validate(estimator=pipeline, X=X_train, y=coffee_train["Country of Origin"], cv=5, return_train_score=True)

knn_tune_grid = GridSearchCV(
     pipeline, param_grid=param_grid, cv=5
 )


knn_model_grid = knn_tune_grid.fit(X_train_1, classifier_coffee_scaled_train["Region"])
accuracies_grid = pd.DataFrame(knn_model_grid.cv_results_)

cross_val_plot = (
     alt.Chart(accuracies_grid, title="Grid Search")
     .mark_line(point=True)
     .encode(
         x=alt.X(
             "param_kneighborsclassifier__n_neighbors",
             title="Neighbors",
             scale=alt.Scale(zero=False),
         ),
         y=alt.Y(
             "mean_test_score", 
            title="Mean Test Score", 
             scale=alt.Scale(zero=False)
         ),
     )
     .configure_axis(labelFontSize=10, titleFontSize=15)
     .properties(width=400, height=300)
 )
cross_val_plot
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# alt.Chart(...)

# %% [markdown]
# *Figure 3.0- GridSearch cross-validation for cluster 3 from k=5 clusters*

# %% [markdown]
# As shown from Figure 2.0 above, the best k-value for classification from cluster 3 will be 44. This is most accurate as it is the highest point of with the greatest mean test score. In the next sections, we will be using k=10 to generate our predicted most profitable bean.

# %%
classifier_coffee_scaled_train_k6, classifier_coffee_scaled_test_k6 = train_test_split(tidy_coffee_cluster_k6_df,test_size=0.2)
classifier_coffee_scaled_train_k6=classifier_coffee_scaled_train_k6.dropna()
classifier_coffee_scaled_test_k6=classifier_coffee_scaled_test_k6.dropna()


X_train_2 = classifier_coffee_scaled_train_k6[["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"]]
y_train_2 = classifier_coffee_scaled_train_k6[["Species", "Country of Origin", "Region"]]
param_grid = { "kneighborsclassifier__n_neighbors": range(1, 70)}

pipeline = make_pipeline(preprocessor,KNeighborsClassifier())
# v_fold_score = cross_validate(estimator=pipeline, X=X_train, y=coffee_train["Country of Origin"], cv=5, return_train_score=True)

knn_tune_grid = GridSearchCV(
     pipeline, param_grid=param_grid, cv=5
 )


knn_model_grid = knn_tune_grid.fit(X_train_2, classifier_coffee_scaled_train_k6["Region"])
accuracies_grid = pd.DataFrame(knn_model_grid.cv_results_)

cross_val_plot = (
     alt.Chart(accuracies_grid, title="Grid Search")
     .mark_line(point=True)
     .encode(
         x=alt.X(
             "param_kneighborsclassifier__n_neighbors",
             title="Neighbors",
             scale=alt.Scale(zero=False),
         ),
         y=alt.Y(
             "mean_test_score", 
            title="Mean Test Score", 
             scale=alt.Scale(zero=False)
         ),
     )
     .configure_axis(labelFontSize=10, titleFontSize=15)
     .properties(width=400, height=300)
 )
cross_val_plot
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# alt.Chart(...)

# %% [markdown]
# *Figure 3.1- GridSearch cross-validation for cluster 5 from k=6 clusters*

# %% [markdown]
# From figure 3.0, the optimal k-value is 24 (the maximum) from the k=6 clusters.

# %%
classifier_coffee_scaled_train_k7, classifier_coffee_scaled_test_k7 = train_test_split(tidy_coffee_cluster_k7_df,test_size=0.2)
classifier_coffee_scaled_train_k7=classifier_coffee_scaled_train_k7.dropna()
classifier_coffee_scaled_test_k7=classifier_coffee_scaled_test_k7.dropna()



X_train_3 = classifier_coffee_scaled_train_k7[["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"]]
y_train_3 = classifier_coffee_scaled_train_k7[["Species", "Country of Origin", "Region"]]
param_grid = { "kneighborsclassifier__n_neighbors": range(1, 70)}

pipeline = make_pipeline(preprocessor,KNeighborsClassifier())
# v_fold_score = cross_validate(estimator=pipeline, X=X_train, y=coffee_train["Country of Origin"], cv=5, return_train_score=True)

knn_tune_grid = GridSearchCV(
     pipeline, param_grid=param_grid, cv=5
 )


knn_model_grid = knn_tune_grid.fit(X_train_3, classifier_coffee_scaled_train_k7["Region"])
accuracies_grid = pd.DataFrame(knn_model_grid.cv_results_)

cross_val_plot = (
     alt.Chart(accuracies_grid, title="Grid Search")
     .mark_line(point=True)
     .encode(
         x=alt.X(
             "param_kneighborsclassifier__n_neighbors",
             title="Neighbors",
             scale=alt.Scale(zero=False),
         ),
         y=alt.Y(
             "mean_test_score", 
            title="Mean Test Score", 
             scale=alt.Scale(zero=False)
         ),
     )
     .configure_axis(labelFontSize=10, titleFontSize=15)
     .properties(width=400, height=300)
 )
cross_val_plot
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# alt.Chart(...)

# %% [markdown]
# *Figure 3.2- GridSearch cross-validation for cluster 3 from k=7 clusters*

# %% [markdown]
# The line plot above shows the optimal k value from the k=7 clusters would be 26.

# %% [markdown]
# As shown below, we have a very scattered and large spread of the data. This suggests that the accuracy of our model will likely be a lot lower than expected simply due to how widespread our data points are.

# %%
classifier_coffee_scaled_train[classifier_coffee_scaled_train["Region"]=="Ethiopia"].count()
classifier_coffee_scaled_train[classifier_coffee_scaled_train["Country of Origin"]=="Columbia"].count()
classifier_coffee_scaled_train[classifier_coffee_scaled_train["Country of Origin"]=="Brazil"].count()
alt.Chart(classifier_coffee_scaled_train).mark_point(opacity=0.25).encode(
    x=alt.X(alt.repeat("row"),type="quantitative"),
    y=alt.Y(alt.repeat("column"),type="quantitative"),
    color=alt.Color("Country of Origin"),
   tooltip =["Species","Country of Origin","Region","Aroma", "Flavor","Aftertaste", "Acidity","Balance",	"Uniformity","cluster"]).repeat(
        row=["Aroma", "Flavor","Aftertaste", "Acidity"],
        column=["Balance",	"Uniformity"]
    ).interactive()
# Out:
# alt.RepeatChart(...)

# %% [markdown]
# *Figure 3.3 - A plot that shows us what the most ideal bean would be according to the highest possible values of our numerical predictors, colour-coded based on the country of origin*

# %% [markdown]
# # **Best Bean Prediction**

# %% [markdown]
# The most ideal bean would score highest on all the variables, so the new observation prediction would ideally score 3, the highest parameter after standardizing the data,  in all categories. The class identification will be based on region and species, since the country of orgin will hence be determined by the region. We will be performing 3 seperate predictions from the generated k-values of the line plots above so that we do not bias our model and have an overall idea of where the most ideal bean would lie. We will be using the remaining 20% of our data to find the accuracy after having trained our model.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_spec = KNeighborsClassifier(n_neighbors=44) 

np.random.seed(1234)

X_train_classifier= classifier_coffee_scaled_train[["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"]]
y_train_classifier = classifier_coffee_scaled_train[["Region","Species"]]
X_test_classifier= classifier_coffee_scaled_test[["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"]]
y_test_classifier = classifier_coffee_scaled_test[["Region","Species"]]


knn_fit = knn_spec.fit(X_train_classifier, y_train_classifier)

class_prediction = knn_fit.predict(X_test_classifier)

new_obs = pd.DataFrame([[3,3,3,3,3,3]], columns=["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"])
bean_prediction = knn_fit.predict(new_obs)
print(bean_prediction)
# Out:
# [['south of minas' 'Arabica']]

# %%
knn_spec = KNeighborsClassifier(n_neighbors=24) 
np.random.seed(1234)

X_train_classifier_k6= classifier_coffee_scaled_train_k6[["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"]]
y_train_classifier_k6 = classifier_coffee_scaled_train_k6[["Region","Species"]]
X_test_classifier_k6= classifier_coffee_scaled_test_k6[["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"]]
y_test_classifier_k6 = classifier_coffee_scaled_test_k6[["Region","Species"]]


knn_fit_k6 = knn_spec.fit(X_train_classifier_k6, y_train_classifier_k6)

class_prediction_k6 = knn_fit_k6.predict(X_test_classifier_k6)

new_obs = pd.DataFrame([[3,3,3,3,3,3]], columns=["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"])
bean_prediction_k6 = knn_fit_k6.predict(new_obs)
print(bean_prediction_k6)
# Out:
# [['huila' 'Arabica']]

# %%
knn_spec = KNeighborsClassifier(n_neighbors=26) 
np.random.seed(1234)

X_train_classifier_k7= classifier_coffee_scaled_train_k7[["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"]]
y_train_classifier_k7 = classifier_coffee_scaled_train_k7[["Region","Species"]]
X_test_classifier_k7= classifier_coffee_scaled_test_k7[["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"]]
y_test_classifier_k7 = classifier_coffee_scaled_test_k7[["Region","Species"]]

knn_fit_k7 = knn_spec.fit(X_train_classifier_k7, y_train_classifier_k7)

class_prediction_k7 = knn_fit_k7.predict(X_test_classifier_k7)

new_obs = pd.DataFrame([[3,3,3,3,3,3]], columns=["Aroma", "Flavor", "Aftertaste", "Acidity", "Balance", "Uniformity"])
bean_prediction_k7 = knn_fit_k7.predict(new_obs)
print(bean_prediction_k7)
# Out:
# [['huila' 'Arabica']]

# %% [markdown]
# As shown above, it is predicted based on the KNN Classification Analysis that the best bean must be of Arabica species. The three predicted regions for each k-value was Huila, which is a region in Columbia.Therefore if we had to choose a bean that would be the most profitable, the bean of the region of Huila and species of Arabica would the bean that scores highest in all our variables and therefore the most profitable. The fact that 3 different k-values used for KNN classification produced the same result ensures the reliability of our result.

# %% [markdown]
# ---
#
# # **Discussion**
#
#   Our predictive question was what bean is the most profitable, which we defined by the criteria generated based on research; the bean with the most desired traits was predicted and identified based on species, region and country of origin.Although this made it easier to quantify the way the bean was determined and is a more holistic and realistic approach in the complex question of 'quality', the sheer number of variables used to rank the beans could have introduced error into our model compared to using 1 or 2, which would have less noise and overall error.
#
#   First we performed a cluster analysis to group the beans into clusters based on the parameters and how high they scored in each of the variables that require the greatest scores. This was done by first generating an elbow plot and then determining the best number of clusters based on the k values with the most dramatic reduction in inertia. We found the three k-values to be 5, 6 and 7. From this we found the best cluster that most likely contained the most proftable bean by taking note of which cluster is on the most top right, meaning it scored high in standardized score for both of the variables. From k=5, cluster 3 was the optimal, and for both k=6 and k=7, cluster 5 was the best. Possible limitations of the clustering method could be that the algorithm assumes perfectly spherical clusters with roughly equal number of data points; of course, this is ideal and not really the case with our data set as the number of data points were not spread evenly with the different k-values.
#
# Next, using only the data points available in the generated clusters, we zoned in on our desired parameters and generated a GrdiSearch line plot that would indicate the most ideal k value within the range of 1-70 to perform a KNN Classification analysis and predict based on the closest nearest neighbours. A potential limitation is that the KNN classifier has a difficult time extrapolating and predicting data beyond the given set of data. We chose the 3 best k-values for classification by generating 3 seperate GridSearch line plots.
#
# Our end result was a bean that was classified with the species "Arabica" and region of "Huila", which is in the country of origin "Columbia". This result is actually reliable since a number of sources have claimed that Columbia as the most popular coffee-selling country. Additionally, according to multiple sources, one of them being Vournas Coffee, the coffee in Huila is grown near the volcano of Nevado del Huila, with the highest elevation of 5364m and the coffee being grown at an average 1500 meters, which is above the desired 1200 meters outlined in our criteria, so this prediction is confirmed. Lastly, according to Perk Coffee Singapore, Arabica beans are often considered 'superior' in taste compared to Robusta.

# %% [markdown]
# **Assessing the accuracy of our model**

# %% [markdown]
# First we will assess the accuracy of the species for all 3 of the predictions. Then we will assess the accuracy of the region of the predicted beans.

# %%
classifier_coffee_scaled_test["Prediction_Region"]=[i for i,y in class_prediction]
classifier_coffee_scaled_test["Prediction_Species"]=[y for i,y in class_prediction]

correct_preds_k5_region=classifier_coffee_scaled_test[classifier_coffee_scaled_test["Prediction_Region"]==classifier_coffee_scaled_test["Region"]]
correct_preds_k5_species=classifier_coffee_scaled_test[classifier_coffee_scaled_test["Prediction_Species"]==classifier_coffee_scaled_test["Species"]]
acc_k5_species=correct_preds_k5_species.shape[0]/classifier_coffee_scaled_test.shape[0]
acc_k5_region=correct_preds_k5_region.shape[0]/classifier_coffee_scaled_test.shape[0]
print(acc_k5_species,acc_k5_region)
# Out:
# 1.0 0.05714285714285714

# %%
classifier_coffee_scaled_test_k6["Prediction_Region"]=[i for i,y in class_prediction_k6]
classifier_coffee_scaled_test_k6["Prediction_Species"]=[y for i,y in class_prediction_k6]

correct_preds_k6_region=classifier_coffee_scaled_test_k6[classifier_coffee_scaled_test_k6["Prediction_Region"]==classifier_coffee_scaled_test_k6["Region"]]
correct_preds_k6_species=classifier_coffee_scaled_test_k6[classifier_coffee_scaled_test_k6["Prediction_Species"]==classifier_coffee_scaled_test_k6["Species"]]
acc_k6_species=correct_preds_k6_species.shape[0]/classifier_coffee_scaled_test_k6.shape[0]
acc_k6_region=correct_preds_k6_region.shape[0]/classifier_coffee_scaled_test_k6.shape[0]
print(acc_k6_species,acc_k6_region)
# Out:
# 0.974025974025974 0.19480519480519481

# %%
classifier_coffee_scaled_test_k7["Prediction_Region"]=[i for i,y in class_prediction_k7]
classifier_coffee_scaled_test_k7["Prediction_Species"]=[y for i,y in class_prediction_k7]

correct_preds_k7_region=classifier_coffee_scaled_test_k7[classifier_coffee_scaled_test_k7["Prediction_Region"]==classifier_coffee_scaled_test_k7["Region"]]
correct_preds_k7_species=classifier_coffee_scaled_test_k7[classifier_coffee_scaled_test_k7["Prediction_Species"]==classifier_coffee_scaled_test_k7["Species"]]
acc_k7_species=correct_preds_k7_species.shape[0]/classifier_coffee_scaled_test_k7.shape[0]
acc_k7_region=correct_preds_k7_region.shape[0]/classifier_coffee_scaled_test_k7.shape[0]
print(acc_k7_species,acc_k7_region)
# Out:
# 0.974025974025974 0.12987012987012986

# %% [markdown]
# # **Accuracy**
#
# As shown above, we tested the accuracy of our model and received a high predicted accuracy for species (Arabica) of 95-98%. This makes sense as a large majority of our available data points were Arabica. For region, however, we received a much lower accuracy of approximately 16-26%. A number of reasons could have caused this, the most probable being the fact that we used a great number of variables and their combinations in coming up with our final prediction. This could have allowed more 'noise' from the quantities we worked with and an accumulated standard deviation and error. It is important to note that although our variables have been quantified on a point scale, they are still largely subjective. For instance "Flavour" and "Aroma" might differ from person to person. Additionally, some people may prefer coffee beans with lower acidity and higher aftertaste; all of which are difficult to model without the previous assumptions that they should all rank high.
#
#  Overall, however, we are satisfied with the approach of our model and in the future we would likely only use a maximum of two variables to predict the class of the most profitable coffee bean. This would make the model a bit more simplistic and less overwhleming when prioritizing and ranking the beans. Additionally, in the future we will likely resample our model a few times so that we would attain a reliable re3presentation of beans from diverse countries of origin and species. All in all, other sources verify the validity of the coffee bean from Huila, Columbia of the species Arabica being the highest quality and therefore most profitable.
#
#  Our model could allow for cafes to make the best decision in where exactly their coffee beans are sourced from and what species is the most reliable. This could allow them to make the most profit and potentially exapnd to birth multi-millionaire corporations in the future, as well as promote creativity for the world of coffee and innovation in our staple beverages to this modern age. The exploration could also demonstrate the optimal conditions for the highest quality coffee bean to grow; all which could be deciphered from the region and country of its harvest. In the future we could consider the economic dimension to the factors that make cafes profitable based on the bean, and create a model that could explore the success of the corporation based on the main demographic of its region.

# %% [markdown]
# Bibliography:
#
#
# ---
#
#
#
#   M. Ridder.”Global Coffee Consumption 2020/21”, Statista, 2023. Available at:
# https://www.statista.com/statistics/292595/global-coffee-consumption/ (Accessed: March 10, 2023).
#
#
#   Fleisher, Judy. “The Effect of Altitude on Coffee Flavor.” Scribblers Coffee Co., 16 Oct. 2017
# Jack Mormon Coffee Co. “The types of coffee processing”, 2021. Available at: https://jackmormoncoffee.com/blogs/news/the-types-of-coffee-processing#:~:text=The%20washed%20process%20is%20able,produces%20the%20highest%20quality%20coffees. (Accessed: March 9, 2023).
#
#
#   Pashley, Tom. “Roaster Guide: Why Is Green Bean Moisture Content Important?” Perfect Daily Grind, Perfect Daily Grind, 13 July 2021.
#
#
#   “Coffee Regions: A Quick Guide to Coffee Growing Regions.” Halo Coffee, https://halo.coffee/blogs/discover/coffee-regions-a-quick-guide-to-coffee-growing-regions#:~:text=Globally%2C%20there%20are%20three%20primary,as%20the%20%22Bean%20Belt%22.
#
#   Vournas Coffee. “Colombia Supremo Huila.” Vournas Coffee Trading, 9 Feb. 2023, https://www.vournascoffee.com/product/colombia-supremo-huila/.
#
#   Perk Coffee. “Arabica Beans vs Robusta Beans. What’s the Difference?” Perk Coffee Singapore, 8 Nov. 2017, perkcoffee.co/sg/arabica-beans-vs-robusta-beans-whats-difference/#:~:text=Despite%20containing%20less%20caffeine%20than.
